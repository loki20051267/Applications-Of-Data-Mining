# %% [markdown]
# <a href="https://colab.research.google.com/github/loki20051267/Applications-Of-Data-Mining/blob/main/LAB_5_Exploratory_Data_Analysis_(EDA).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("titanic_dataset_250.csv")

print(df.info())
print(df.describe())
print("Missing Values:\n", df.isnull().sum())

df.loc[:, 'Age'] = df['Age'].fillna(df['Age'].median())
df.loc[:, 'Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

print("Missing Values After Imputation:\n", df.isnull().sum())

plt.figure(figsize=(10, 6))
numerical_df = df.select_dtypes(include=['number'])
sns.heatmap(numerical_df.corr(), annot=True, cmap='coolwarm', fmt='.2f', cbar=True)
plt.title('Correlation Matrix')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Passenger ID             250 non-null    int64
#  1   Age                      250 non-null    int64
#  2   Gender                   250 non-null    object
#  3   Class                    250 non-null    object
#  4   Survived                 250 non-null    int64
#  5   Fare                     250 non-null    float64
#  6   Embarked                 250 non-null    object
#  7   Siblings/Spouses Aboard  250 non-null    int64
#  8   Parents/Children Aboard  250 non-null    int64
# dtypes: float64(1), int64(5), object(3)
# memory usage: 17.7+ KB
# None
#        Passenger ID         Age    Survived        Fare  \
# count    250.000000  250.000000  250.000000  250.000000
# mean     125.500000   38.584000    0.460000   98.183680
# ...
